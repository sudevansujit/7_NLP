# %% [markdown]
# # Biomedical Named Entity Recognition

# %%
import spacy
import scispacy

# %%
from spacy import displacy

# %%
text = open('diabetes.txt').read()

# %%
text[:100]
# Out:
# 'The prevalence of diabetes is rapidly rising all over the globe at an alarming rate. Over the last t'

# %%
text[-100:]
# Out:
# 'resistance and secretory defect during pregnancy results in GDM [39-45].\nDiabetic ketoacidosis (DKA)'

# %%
len(text)
# Out:
# 11409

# %%
spacynlp = spacy.load('en_core_web_sm')
scinlp = spacy.load('en_core_sci_sm')

# %% [markdown]
#    **Python function display_entities()accepts a model and document to return a displacy image and word entities. The function will be used on three different scispaCy models and the tests document. The function can be adjusted as needed. E.g To view dependency parsing instead of entities use displacy.render(doc,jupyter=True,style='dep')**

# %%
def display_entities(model, text):
    scinlp = spacy.load(model)
    doc = scinlp(text)
    displacy_image = displacy.render(doc, style = 'ent')
    entity_label = set([(token.text, token.label_) for token in doc.ents])
    return  entity_label

# %%
display_entities('en_core_web_sm', text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The prevalence of diabetes is rapidly rising all over the globe at an alarming rate. Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last three decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the status of diabetes has been changed, earlier it was considered as a mild disorder of the elderly people. Now it becomes a major cause of morbidity and mortality affecting the youth and middle aged people. According to the Diabetes Atlas 2006 published by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the International Diabetes Federation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the number of people with diabetes in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  currently
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     around 40.9 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  is expected to rise to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     69.9 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2025
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  unless urgent preventive steps are taken. The main force of the epidemic of diabetes is the rapid epidemiological transition associated with changes in dietary patterns and decreased physical activity as evident from the higher prevalence of diabetes in the urban population. The most disturbing trend is the shift in age of onset of diabetes to a younger age in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the recent years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . This could have long lasting adverse effects on nation’s health and economy. Therefore, it is necessary to identify the diabetic patients at the earliest and provide appropriate lifestyle intervention in preventing or postponing the onset of diabetes. In the present review, detailed mechanism and management of the diabetes have been emphasized.</br></br></br></br> </br></br>Key words</br>Diabetes; prevalence; Diabetic acidosis; pathophysiology.</br>INTRODUCTION</br>Diabetes mellitus is not a single disorder, it represents a series of metabolic conditions associated with hyperglycaemia and caused by defects in insulin secretion and/or insulin action. Exposure to chronic hyperglycaemia may result in microvascular complications in the retina, kidney or periphera.</br>Mechanism</br>Diabetes mellitus (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) is a set of related diseases in which the body cannot regulate the amount of sugar (specifically, glucose) in the blood.</br>The blood delivers glucose to provide the body with energy to perform all of a person's
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  activities. The liver converts the food a person eats into glucose. The glucose is then released into the bloodstream. In a healthy person, the blood glucose level is regulated by several hormones, primarily insulin.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Insulin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is produced by the pancreas, a small organ between the stomach and liver. The pancreas also makes other important enzymes released directly into the gut that helps digest food.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Insulin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  allows glucose to move out of the blood into cells throughout the body where it is used for fuel. People suffered diabetes either do not produce enough insulin (type
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  diabetes) or cannot use insulin properly (type
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  diabetes), or both (which occurs with several forms of diabetes). In diabetes, glucose in the blood cannot move efficiently into cells, so blood glucose levels remain high. This not only starves all the cells that need the glucose for fuel, but also harms certain organs and tissues exposed to the high glucose levels.</br>TYPES OF DIABETES</br>There are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  main types of diabetes type
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and type
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em
# {('1', 'CARDINAL'),
#  ('2', 'CARDINAL'),
#  ('2025', 'DATE'),
#  ('27', 'CARDINAL'),
#  ('2nd', 'ORDINAL'),
#  ('39', 'CARDINAL'),
#  ('4/4', 'CARDINAL'),
#  ('6', 'CARDINAL'),
#  ('67%', 'PERCENT'),
#  ('69.9 million', 'CARDINAL'),
#  ('Addison', 'PERSON'),
#  ('Caucasians', 'NORP'),
#  ('DM', 'ORG'),
#  ('Forty', 'CARDINAL'),
#  ('GAD', 'ORG'),
#  ('GDM', 'ORG'),
#  ('Hashimoto', 'GPE'),
#  ('Hyperglycemia', 'PRODUCT'),
#  ('India', 'GPE'),
#  ('Insulin', 'ORG'),
#  ('Insulin', 'PERSON'),
#  ('Latino', 'PERSON'),
#  ('Seshiah et', 'PERSON'),
#  ('T1DM', 'GPE'),
#  ('TRIGR', 'ORG'),
#  ('VAT', 'ORG'),
#  ('VAT', 'PRODUCT'),
#  ('approximately 5%', 'PERCENT'),
#  ('approximately 7%', 'PERCENT'),
#  ('around 40.9 million', 'CARDINAL'),
#  ('daily', 'DATE'),
#  ('first', 'ORDINAL'),
#  ('hyperglucagonaemia', 'GPE'),
#  ('insulin autoantibody', 'PERSON'),
#  ('meta-analysis[26', 'PERSON'),
#  ('more than 2,00,000', 'CARDINAL'),
#  ('obese', 'NORP'),
#  ('one', 'CARDINAL'),
#  ('pregnancy[22', 'PRODUCT'),
#  ('second', 'ORDINAL'),
#  ('the International Diabetes Federation', 'ORG'),
#  ('the last three decades', 'DATE'),
#  ('the recent years', 'DATE'),
#  ('two', 'CARDINAL'),
#  ('year[23', 'PRODUCT')}

# %%
display_entities('en_core_sci_sm', text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prevalence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  is rapidly rising all over the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     globe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  at an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alarming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# . Over the last three
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# , the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     status
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  has been
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     changed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# , earlier it was considered as a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mild disorder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     elderly people
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# . Now it becomes a major cause of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morbidity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mortality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  affecting the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     youth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     middle aged people
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# . According to the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  Atlas 2006 published by the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     International Diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  Federation, the number of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     people
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  currently around 40.9
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  is expected to rise to 69.9 million by 2025 unless urgent
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     preventive steps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  are taken. The main
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     force
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertic
# {('Abnormalities', 'ENTITY'),
#  ('Addison’s disease', 'ENTITY'),
#  ('Autoimmunity', 'ENTITY'),
#  ('Caucasians', 'ENTITY'),
#  ('Chronic fuel', 'ENTITY'),
#  ('Cytokines', 'ENTITY'),
#  ('DIABETES', 'ENTITY'),
#  ('DKA', 'ENTITY'),
#  ('DM', 'ENTITY'),
#  ('DQ', 'ENTITY'),
#  ('DR', 'ENTITY'),
#  ('DR3/4', 'ENTITY'),
#  ('Diabetes', 'ENTITY'),
#  ('Diabetes mellitus', 'ENTITY'),
#  ('Diabetic acidosis', 'ENTITY'),
#  ('Diabetic ketoacidosis', 'ENTITY'),
#  ('Eisenbarth', 'ENTITY'),
#  ('Exposure to', 'ENTITY'),
#  ('GAD', 'ENTITY'),
#  ('GDM', 'ENTITY'),
#  ('GLP-1', 'ENTITY'),
#  ('Gestational diabetes', 'ENTITY'),
#  ('Gestational diabetes mellitus', 'ENTITY'),
#  ('HLA', 'ENTITY'),
#  ('Hashimoto’s thyroiditis', 'ENTITY'),
#  ('Hyperglycemia', 'ENTITY'),
#  ('IAA', 'ENTITY'),
#  ('ICA512/IA-2', 'ENTITY'),
#  ('India', 'ENTITY'),
#  ('Insulin', 'ENTITY'),
#  ('Insulin resistance', 'ENTITY'),
#  ('Insulitis', 'ENTITY'),
#  ('International Diabetes', 'ENTITY'),
#  ('Ketones', 'ENTITY'),
#  ('Latino women', 'ENTITY'),
#  ('Mechanism\nDiabetes mellitus', 'ENTITY'),
#  ('Overweight', 'ENTITY'),
#  ('Pathophysiology\nType 1 diabetes', 'ENTITY'),
#  ('Patients', 'ENTITY'),
#  ('People', 'ENTITY'),
#  ('Pregnancy', 'ENTITY'),
#  ('SAT', 'ENTITY'),
#  ('Seshiah', 'ENTITY'),
#  ('Susceptible', 'ENTITY'),
#  ('T-cell dependent autoimmunity', 'ENTITY'),
#  ('T1DM', 'ENTITY'),
#  ('TRIGR', 'ENTITY'),
#  ('Table 1', 'ENTITY'),
#  ('TrialNet', 'ENTITY'),
#  ('Type 1 diabetes\nType 1 diabetes', 'ENTITY'),
#  ('Type 2 diabetes', 'ENTITY'),
#  ('Type 2 diabetes mellitus', 'ENTITY'),
#  ('VAT', 'ENTITY'),
#  ('abnormal', 'ENTITY'),
#  ('absence', 'ENTITY'),
#  ('accounts', 'ENTITY'),
#  ('accumulation', 'ENTITY'),
#  ('adaptive responses', 'ENTITY'),
#  ('adiponectin', 'ENTITY'),
#  ('adipose tissue', 'ENTITY'),
#  ('adverse effects', 'ENTITY'),
#  ('affected', 'ENTITY'),
#  ('age', 'ENTITY'),
#  ('alarming', 'ENTITY'),
#  ('alleles', 'ENTITY'),
#  ('alterations', 'ENTITY'),
#  ('amount', 'ENTITY'),
#  ('amyloid', 'ENTITY'),
#  ('antibodies', 'ENTITY'),
#  ('associated with', 'ENTITY'),
#  ('autoimmune destruction', 'ENTITY'),
#  ('autoimmune disease', 'ENTITY'),
#  ('autoimmune diseases', 'ENTITY'),
#  ('autoimmune process', 'ENTITY'),
#  ('begins', 'ENTITY'),
#  ('beta cell function', 'ENTITY'),
#  ('blood', 'ENTITY'),
#  ('blood acidic', 'ENTITY'),
#  ('blood delivers', 'ENTITY'),
#  ('blood glucose level', 'ENTITY'),
#  ('blood glucose levels', 'ENTITY'),
#  ('blood sugar', 'ENTITY'),
#  ('bloodstream', 'ENTITY'),
#  ('body', 'ENTITY'),
#  ('body avoid', 'ENTITY'),
#  ('body functions', 'ENTITY'),
#  ('brain', 'ENTITY'),
#  ('calories', 'ENTITY'),
#  ('carbohydrate', 'ENTITY'),
#  ('cases', 'ENTITY'),
#  ('celiac disease', 'ENTITY'),
#  ('cell', 'ENTITY'),
#  ('cell function', 'ENTITY'),
#  ('cells', 'ENTITY'),
#  ('changed', 'ENTITY'),
#  ('changes', 'ENTITY'),
#  ('characteristics', 'ENTITY'),
#  ('chronic', 'ENTITY'),
#  ('chronic exposure to', 'ENTITY'),
#  ('chronic hyperglycaemia', 'ENTITY'),
#  ('clinical', 'ENTITY'),
#  ('clinical relevance', 'ENTITY'),
#  ('coma', 'ENTITY'),
#  ('combination', 'ENTITY'),
#  ('compensate', 'ENTITY'),
#  ('compensatory hyperinsulinaemia', 'ENTITY'),
#  ('complicates', 'ENTITY'),
#  ('complications', 'ENTITY'),
#  ('concentrations', 'ENTITY'),
#  ('confusion', 'ENTITY'),
#  ('contributors', 'ENTITY'),
#  ('cortisol', 'ENTITY'),
#  ('counter-regulatory hormones', 'ENTITY'),
#  ('cytokine signalling', 'ENTITY'),
#  ('cytokines', 'ENTITY'),
#  ('death', 'ENTITY'),
#  ('decades', 'ENTITY'),
#  ('decline', 'ENTITY'),
#  ('decreased', 'ENTITY'),
#  ('defects', 'ENTITY'),
#  ('delay', 'ENTITY'),
#  ('deposited', 'ENTITY'),
#  ('deprived', 'ENTITY'),
#  ('deterioration', 'ENTITY'),
#  ('development', 'ENTITY'),
#  ('develops', 'ENTITY'),
#  ('diabetes', 'ENTITY'),
#  ('diabetes type 1', 'ENTITY'),
#  ('diabetic', 'ENTITY'),
#  ('diabetogenic state', 'ENTITY'),
#  ('diagnosis', 'ENTITY'),
#  ('dietary factors', 'ENTITY'),
#  ('dietary patterns', 'ENTITY'),
#  ('diseases', 'ENTITY'),
#  ('disorder', 'ENTITY'),
#  ('dispose', 'ENTITY'),
#  ('earliest', 'ENTITY'),
#  ('economy', 'ENTITY'),
#  ('ectopic', 'ENTITY'),
#  ('elderly people', 'ENTITY'),
#  ('endocrine', 'ENTITY'),
#  ('endogenous', 'ENTITY'),
#  ('energy', 'ENTITY'),
#  ('enteroviruses', 'ENTITY'),
#  ('environmental', 'ENTITY'),
#  ('environmental factors', 'ENTITY'),
#  ('enzymatic defect', 'ENTITY'),
#  ('enzymes', 'ENTITY'),
#  ('epidemic', 'ENTITY'),
#  ('epidemiological transition', 'ENTITY'),
#  ('event', 'ENTITY'),
#  ('expansion', 'ENTITY'),
#  ('exposed to', 'ENTITY'),
#  ('failure', 'ENTITY'),
#  ('fat', 'ENTITY'),
#  ('fatty acids', 'ENTITY'),
#  ('fetal', 'ENTITY'),
#  ('first-degree relative', 'ENTITY'),
#  ('food', 'ENTITY'),
#  ('force', 'ENTITY'),
#  ('fuel', 'ENTITY'),
#  ('genetic', 'ENTITY'),
#  ('genetic loci', 'ENTITY'),
#  ('genetically', 'ENTITY'),
#  ('genetically susceptible', 'ENTITY'),
#  ('genome-wide association study', 'ENTITY'),
#  ('gestational diabetes mellitus', 'ENTITY'),
#  ('globe', 'ENTITY'),
#  ('glucagon', 'ENTITY'),
#  ('glucagon secretion', 'ENTITY'),
#  ('glucokinase', 'ENTITY'),
#  ('glucose', 'ENTITY'),
#  ('glucose intolerance', 'ENTITY'),
#  ('glucose intolerance progresses', 'ENTITY'),
#  ('glucose levels', 'ENTITY'),
#  ('glucose production', 'ENTITY'),
#  ('glucose tolerance', 'ENTITY'),
#  ('glucotoxicity', 'ENTITY'),
#  ('glutamic acid decarboxylase', 'ENTITY'),
#  ('gradual', 'ENTITY'),
#  ('growth hormone', 'ENTITY'),
#  ('gut', 'ENTITY'),
#  ('harms', 'ENTITY'),
#  ('healthy', 'ENTITY'),
#  ('healthy person', 'ENTITY'),
#  ('heart', 'ENTITY'),
#  ('heterogeneous', 'ENTITY'),
#  ('high blood sugar', 'ENTITY'),
#  ('higher', 'ENTITY'),
#  ('histocompatibility', 'ENTITY'),
#  ('hormone', 'ENTITY'),
#  ('hormones', 'ENTITY'),
#  ('human', 'ENTITY'),
#  ('hyper glycaemia', 'ENTITY'),
#  ('hyperglucagonaemia', 'ENTITY'),
#  ('hyperglycaemia', 'ENTITY'),
#  ('hyperglycemia', 'ENTITY'),
#  ('hypoadiponectinaemia', 'ENTITY'),
#  ('hypoglycemia', 'ENTITY'),
#  ('imbalance', 'ENTITY'),
#  ('impaired', 'ENTITY'),
#  ('inability', 'ENTITY'),
#  ('incidence', 'ENTITY'),
#  ('increase', 'ENTITY'),
#  ('increased', 'ENTITY'),
#  ('increasing', 'ENTITY'),
#  ('incretin glucagon-like peptide 1', 'ENTITY'),
#  ('incretin response', 'ENTITY'),
#  ('individual', 'ENTITY'),
#  ('individuals', 'ENTITY'),
#  ('individuals[25', 'ENTITY'),
#  ('inflammation', 'ENTITY'),
#  ('inflammatory signals', 'ENTITY'),
#  ('influences', 'ENTITY'),
#  ('insulin', 'ENTITY'),
#  ('insulin action', 'ENTITY'),
#  ('insulin autoantibody', 'ENTITY'),
#  ('insulin properly', 'ENTITY'),
#  ('insulin receptor', 'ENTITY'),
#  ('insulin release', 'ENTITY'),
#  ('insulin resistance', 'ENTITY'),
#  ('insulin secretion', 'ENTITY'),
#  ('insulin sensitivity', 'ENTITY'),
#  ('insulin therapy', 'ENTITY'),
#  ('insulin-producing ß-cells', 'ENTITY'),
#  ('interaction', 'ENTITY'),
#  ('interleukin 6', 'ENTITY'),
#  ('international networks', 'ENTITY'),
#  ('intervention', 'ENTITY'),
#  ('interventional trials', 'ENTITY'),
#  ('islet', 'ENTITY'),
#  ('islet ß cells', 'ENTITY'),
#  ('ketoacidosis', 'ENTITY'),
#  ('ketones', 'ENTITY'),
#  ('kidney', 'ENTITY'),
#  ('lean', 'ENTITY'),
#  ('leptin', 'ENTITY'),
#  ('lies', 'ENTITY'),
#  ('life', 'ENTITY'),
#  ('life threatening', 'ENTITY'),
#  ('lifestyle', 'ENTITY'),
#  ('lipotoxicity', 'ENTITY'),
#  ('liver', 'ENTITY'),
#  ('liver fat.[30,31', 'ENTITY'),
#  ('loss of consciousness', 'ENTITY'),
#  ('low blood sugar', 'ENTITY'),
#  ('maintenance', 'ENTITY'),
#  ('management', 'ENTITY'),
#  ('management issues', 'ENTITY'),
#  ('maternal', 'ENTITY'),
#  ('mechanism', 'ENTITY'),
#  ('mechanisms', 'ENTITY'),
#  ('meta-analysis[26', 'ENTITY'),
#  ('metabolic conditions', 'ENTITY'),
#  ('metabolic defects', 'ENTITY'),
#  ('metabolic disorder', 'ENTITY'),
#  ('microvascular complications', 'ENTITY'),
#  ('middle aged people', 'ENTITY'),
#  ('mild disorder', 'ENTITY'),
#  ('million', 'ENTITY'),
#  ('minimal', 'ENTITY'),
#  ('morbidity', 'ENTITY'),
#  ('mortality', 'ENTITY'),
#  ('mother', 'ENTITY'),
#  ('myasthenia gravis', 'ENTITY'),
#  ('nation', 'ENTITY'),
#  ('near-normal blood', 'ENTITY'),
#  ('non-esterifies fatty acids', 'ENTITY'),
#  ('nonsuppressed', 'ENTITY'),
#  ('normal', 'ENTITY'),
#  ('normal pregnant control', 'ENTITY'),
#  ('nutrient', 'ENTITY'),
#  ('nutrient-induced damage', 'ENTITY'),
#  ('obese', 'ENTITY'),
#  ('obesity', 'ENTITY'),
#  ('onset', 'ENTITY'),
#  ('onset of', 'ENTITY'),
#  ('organ', 'ENTITY'),
#  ('organs', 'ENTITY'),
#  ('overcome', 'ENTITY'),
#  ('overt', 'ENTITY'),
#  ('overweight', 'ENTITY'),
#  ('oxidative stress', 'ENTITY'),
#  ('pancreas', 'ENTITY'),
#  ('pancreatic a-cell dysfunction', 'ENTITY'),
#  ('pancreatic ß-cell dysfunction', 'ENTITY'),
#  ('parent', 'ENTITY'),
#  ('partition', 'ENTITY'),
#  ('pathogenesis', 'ENTITY'),
#  ('pathogenic', 'ENTITY'),
#  ('pathophysiology', 'ENTITY'),
#  ('pathways', 'ENTITY'),
#  ('patients', 'ENTITY'),
#  ('people', 'ENTITY'),
#  ('people[28,29', 'ENTITY'),
#  ('period', 'ENTITY'),
#  ('periphera', 'ENTITY'),
#  ('peripheral insulin resistance', 'ENTITY'),
#  ('person eats', 'ENTITY'),
#  ("person's", 'ENTITY'),
#  ('phase', 'ENTITY'),
#  ('phosphorylation', 'ENTITY'),
#  ('physical activity', 'ENTITY'),
#  ('placental', 'ENTITY'),
#  ('placental hormones', 'ENTITY'),
#  ('postponing', 'ENTITY'),
#  ('prandial', 'ENTITY'),
#  ('pre-diabetes', 'ENTITY'),
#  ('pregnancy', 'ENTITY'),
#  ('pregnancy[22', 'ENTITY'),
#  ('pregnant state', 'ENTITY'),
#  ('prevalence', 'ENTITY'),
#  ('prevent', 'ENTITY'),
#  ('preventing', 'ENTITY'),
#  ('preventive steps', 'ENTITY'),
#  ('progesterone', 'ENTITY'),
#  ('progression', 'ENTITY'),
#  ('progressive', 'ENTITY'),
#  ('prolactin', 'ENTITY'),
#  ('prolonged', 'ENTITY'),
#  ('raised', 'ENTITY'),
#  ('rate', 'ENTITY'),
#  ('reduced', 'ENTITY'),
#  ('reduction', 'ENTITY'),
#  ('released', 'ENTITY'),
#  ('research', 'ENTITY'),
#  ('resistant', 'ENTITY'),
#  ('results', 'ENTITY'),
#  ('retina', 'ENTITY'),
#  ('retinol-binding protein 4.1[14', 'ENTITY'),
#  ('reverse', 'ENTITY'),
#  ('review', 'ENTITY'),
#  ('risk', 'ENTITY'),
#  ('screening', 'ENTITY'),
#  ('secrete', 'ENTITY'),
#  ('secretion', 'ENTITY'),
#  ('secretory defect', 'ENTITY'),
#  ('shift', 'ENTITY'),
#  ('skeletal muscle', 'ENTITY'),
#  ('slow down', 'ENTITY'),
#  ('status', 'ENTITY'),
#  ('steady state', 'ENTITY'),
#  ('stomach', 'ENTITY'),
#  ('storage', 'ENTITY'),
#  ('study', 'ENTITY'),
#  ('subcutaneous adipose tissue', 'ENTITY'),
#  ('substrate', 'ENTITY'),
#  ('sufficient', 'ENTITY'),
#  ('sugar', 'ENTITY'),
#  ('suppressor', 'ENTITY'),
#  ('suppressors', 'ENTITY'),
#  ('susceptibility', 'ENTITY'),
#  ('susceptible', 'ENTITY'),
#  ('tissue damage', 'ENTITY'),
#  ('tissue necrosis factor', 'ENTITY'),
#  ('tissues', 'ENTITY'),
#  ('toxins', 'ENTITY'),
#  ('trimester', 'ENTITY'),
#  ('tumour necrosis factor a', 'ENTITY'),
#  ('type 1 diabetes', 'ENTITY'),
#  ('type 2', 'ENTITY'),
#  ('type 2 diabetes', 'ENTITY'),
#  ('type 2 diabetes[7', 'ENTITY'),
#  ('type of', 'ENTITY'),
#  ('type-2 diabetes', 'ENTITY'),
#  ('unidentified', 'ENTITY'),
#  ('urban population', 'ENTITY'),
#  ('variable degrees', 'ENTITY'),
#  ('visceral adipose tissue', 'ENTITY'),
#  ('women', 'ENTITY'),
#  ('year[23', 'ENTITY'),
#  ('years', 'ENTITY'),
#  ('younger age', 'ENTITY'),
#  ('youth', 'ENTITY'),
#  ('ß-cell compensation', 'ENTITY'),
#  ('ß-cell destruction', 'ENTITY'),
#  ('ß-cell function', 'ENTITY'),
#  ('ß-cells', 'ENTITY'),
#  ('’s', 'ENTITY')}

# %%
display_entities('en_ner_bc5cdr_md', text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The prevalence of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  is rapidly rising all over the globe at an alarming rate. Over the last three decades, the status of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  has been changed, earlier it was considered as a mild
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     disorder of the elderly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  people. Now it becomes a major cause of morbidity and mortality affecting the youth and middle aged people. According to the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  Atlas 2006 published by the International
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  Federation, the number of people with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  in India currently around 40.9 million is expected to rise to 69.9 million by 2025 unless urgent preventive steps are taken. The main force of the epidemic of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  is the rapid epidemiological transition associated with changes in dietary patterns and decreased physical activity as evident from the higher prevalence of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  in the urban population. The most disturbing trend is the shift in age of onset of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  to a younger age in the recent years. This could have long lasting adverse effects on nation’s health and economy. Therefore, it is necessary to identify the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  patients at the earliest and provide appropriate lifestyle intervention in preventing or postponing the onset of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# . In the present review, detailed mechanism and management of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  have been emphasized.</br></br></br></br> </br></br>Key words</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# ; prevalence;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diabetic acidosis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# ; pathophysiology.</br>INTRODUCTION</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diabetes mellitus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  is not a single disorder, it represents a series of metabolic conditions associated with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hyperglycaemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  and caused by defects in insulin secretion and/or insulin action. Exposure to chronic
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hyperglycaemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  may result in microvascular complications in the retina, kidney or periphera.</br>Mechanism</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diabetes mellitus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# ) is a set of related diseases in which the body cannot regulate the
# {('Addison’s disease', 'DISEASE'),
#  ('Autoimmunity', 'DISEASE'),
#  ('DKA', 'DISEASE'),
#  ('DM', 'DISEASE'),
#  ('DR', 'DISEASE'),
#  ('Diabetes', 'DISEASE'),
#  ('Diabetes mellitus', 'DISEASE'),
#  ('Diabetic acidosis', 'DISEASE'),
#  ('Diabetic ketoacidosis', 'DISEASE'),
#  ('Eisenbarth', 'CHEMICAL'),
#  ('GDM', 'DISEASE'),
#  ('Gestational diabetes', 'DISEASE'),
#  ('Gestational diabetes mellitus', 'DISEASE'),
#  ('Hashimoto’s thyroiditis', 'DISEASE'),
#  ('Hyperglycemia', 'DISEASE'),
#  ('IAA', 'CHEMICAL'),
#  ('Insulitis', 'DISEASE'),
#  ('Ketones', 'CHEMICAL'),
#  ('Overweight', 'DISEASE'),
#  ('Seshiah', 'CHEMICAL'),
#  ('T1DM', 'DISEASE'),
#  ('TRIGR', 'DISEASE'),
#  ('TrialNet', 'CHEMICAL'),
#  ('Type 1 diabetes\nT1DM', 'DISEASE'),
#  ('Type 2 diabetes', 'DISEASE'),
#  ('amyloid formation[18–20', 'CHEMICAL'),
#  ('autoimmune disease', 'DISEASE'),
#  ('autoimmune diseases', 'DISEASE'),
#  ('autoimmunity', 'DISEASE'),
#  ('blood glucose', 'DISEASE'),
#  ('blood sugar', 'DISEASE'),
#  ('carbohydrate intolerance', 'DISEASE'),
#  ('celiac disease', 'DISEASE'),
#  ('coma', 'DISEASE'),
#  ('confusion', 'DISEASE'),
#  ('cortisol', 'CHEMICAL'),
#  ('death', 'DISEASE'),
#  ('diabetes', 'DISEASE'),
#  ('diabetic', 'DISEASE'),
#  ('disorder', 'DISEASE'),
#  ('disorder of the elderly', 'DISEASE'),
#  ('fat.[30,31', 'CHEMICAL'),
#  ('fatty acids', 'CHEMICAL'),
#  ('gestational diabetes mellitus', 'DISEASE'),
#  ('glucose', 'CHEMICAL'),
#  ('glucose', 'DISEASE'),
#  ('glucose intolerance', 'DISEASE'),
#  ('glucotoxicity', 'DISEASE'),
#  ('glutamic acid', 'CHEMICAL'),
#  ('hyperglucagonaemia', 'DISEASE'),
#  ('hyperglycaemia', 'DISEASE'),
#  ('hyperglycemia', 'DISEASE'),
#  ('hyperinsulinaemia', 'DISEASE'),
#  ('hypoadiponectinaemia', 'DISEASE'),
#  ('hypoglycemia', 'DISEASE'),
#  ('inability of islet ß', 'DISEASE'),
#  ('inflammation', 'DISEASE'),
#  ('ketoacidosis', 'DISEASE'),
#  ('leptin', 'CHEMICAL'),
#  ('lipotoxicity', 'DISEASE'),
#  ('loss of consciousness', 'DISEASE'),
#  ('metabolic defects', 'DISEASE'),
#  ('metabolic disorder', 'DISEASE'),
#  ('myasthenia gravis', 'DISEASE'),
#  ('necrosis', 'DISEASE'),
#  ('nonsuppressed', 'CHEMICAL'),
#  ('obesity', 'DISEASE'),
#  ('pancreatic a-cell dysfunction', 'DISEASE'),
#  ('pancreatic ß-cell dysfunction', 'DISEASE'),
#  ('pre-diabetes', 'DISEASE'),
#  ('pregnancy[22', 'CHEMICAL'),
#  ('progesterone', 'CHEMICAL'),
#  ('tissue damage', 'DISEASE'),
#  ('tumour necrosis', 'DISEASE'),
#  ('type 2 diabetes', 'DISEASE')}

# %%
display_entities('en_ner_bionlp13cg_md', text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The prevalence of diabetes is rapidly rising all over the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     globe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TISSUE</span>
# </mark>
#  at an alarming rate. Over the last three decades, the status of diabetes has been changed, earlier it was considered as a mild disorder of the elderly
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     people
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
# . Now it becomes a major cause of morbidity and mortality affecting the youth and middle aged
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     people
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
# . According to the Diabetes Atlas 2006 published by the International Diabetes Federation, the number of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     people
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
#  with diabetes in India currently around 40.9 million is expected to rise to 69.9 million by 2025 unless urgent preventive steps are taken. The main force of the epidemic of diabetes is the rapid epidemiological transition associated with changes in dietary patterns and decreased physical activity as evident from the higher prevalence of diabetes in the urban population. The most disturbing trend is the shift in age of onset of diabetes to a younger age in the recent years. This could have long lasting adverse effects on nation
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  health and economy. Therefore, it is necessary to identify the diabetic
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patients
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
#  at the earliest and provide appropriate lifestyle intervention in preventing or postponing the onset of diabetes. In the present review, detailed mechanism and management of the diabetes have been emphasized.</br></br></br></br> </br></br>Key words</br>Diabetes; prevalence; Diabetic acidosis; pathophysiology.</br>INTRODUCTION</br>Diabetes mellitus is not a single disorder, it represents a series of metabolic conditions associated with hyperglycaemia and caused by defects in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insulin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  secretion and/or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insulin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  action. Exposure to chronic hyperglycaemia may result in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     microvascular
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TISSUE</span>
# </mark>
#  complications in the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     retina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MULTI-TISSUE_STRUCTURE</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kidney
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  or periphera.</br>Mechanism</br>Diabetes mellitus (DM) is a set of related diseases in which the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     body
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  cannot regulate the amount of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sugar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
#  (specifically,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     glucose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
# ) in the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANISM_SUBSTANCE</span>
# </mark>
# .</br>The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANISM_SUBSTANCE</span>
# </mark>
#  delivers
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     glucose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
#  to provide the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     body
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  with energy to perform all of a person's daily activities. The
# <mark class="entity" style="background: #ddd; padding: 0.
# {('18.9%[24', 'SIMPLE_CHEMICAL'),
#  ('Cytokines', 'CELLULAR_COMPONENT'),
#  ('DKA', 'SIMPLE_CHEMICAL'),
#  ('DQ', 'GENE_OR_GENE_PRODUCT'),
#  ('DR 4/4', 'GENE_OR_GENE_PRODUCT'),
#  ('GAD', 'GENE_OR_GENE_PRODUCT'),
#  ('GDM', 'CANCER'),
#  ('GDM', 'PATHOLOGICAL_FORMATION'),
#  ('GLP-1', 'SIMPLE_CHEMICAL'),
#  ('IAA', 'SIMPLE_CHEMICAL'),
#  ('Insulin', 'GENE_OR_GENE_PRODUCT'),
#  ('Ketones', 'SIMPLE_CHEMICAL'),
#  ('Latino women', 'ORGANISM'),
#  ('Patients', 'ORGANISM'),
#  ('People', 'ORGANISM'),
#  ('SAT', 'TISSUE'),
#  ('T-cell', 'CELL'),
#  ('VAT', 'TISSUE'),
#  ('adiponectin', 'GENE_OR_GENE_PRODUCT'),
#  ('adipose tissue', 'TISSUE'),
#  ('amyloid formation[18–20', 'GENE_OR_GENE_PRODUCT'),
#  ('beta cell', 'CELL'),
#  ('blood', 'ORGANISM_SUBSTANCE'),
#  ('blood glucose', 'ORGANISM_SUBSTANCE'),
#  ('blood sugar', 'MULTI-TISSUE_STRUCTURE'),
#  ('blood sugar', 'ORGANISM_SUBSTANCE'),
#  ('bloodstream', 'ORGANISM'),
#  ('body', 'ORGAN'),
#  ('body', 'ORGANISM_SUBDIVISION'),
#  ('body', 'TISSUE'),
#  ('brain', 'ORGAN'),
#  ('carbohydrate', 'SIMPLE_CHEMICAL'),
#  ('celiac', 'ORGAN'),
#  ('cells', 'CELL'),
#  ('counter-regulatory hormones', 'SIMPLE_CHEMICAL'),
#  ('enteroviruses', 'ORGANISM'),
#  ('fat', 'TISSUE'),
#  ('father', 'SIMPLE_CHEMICAL'),
#  ('fatty acids', 'SIMPLE_CHEMICAL'),
#  ('fetal', 'TISSUE'),
#  ('globe', 'TISSUE'),
#  ('glucagon', 'GENE_OR_GENE_PRODUCT'),
#  ('glucagon', 'SIMPLE_CHEMICAL'),
#  ('glucokinase', 'GENE_OR_GENE_PRODUCT'),
#  ('glucose', 'SIMPLE_CHEMICAL'),
#  ('glutamic acid decarboxylase', 'GENE_OR_GENE_PRODUCT'),
#  ('gut', 'ORGAN'),
#  ('heart', 'ORGAN'),
#  ('hormones', 'SIMPLE_CHEMICAL'),
#  ('human placental lactogen', 'ORGANISM'),
#  ('incretin', 'SIMPLE_CHEMICAL'),
#  ('incretin glucagon-like peptide 1', 'GENE_OR_GENE_PRODUCT'),
#  ('individuals[25', 'GENE_OR_GENE_PRODUCT'),
#  ('insulin', 'GENE_OR_GENE_PRODUCT'),
#  ('insulin receptor', 'GENE_OR_GENE_PRODUCT'),
#  ('interleukin 6', 'GENE_OR_GENE_PRODUCT'),
#  ('islet ß', 'CELL'),
#  ('islet ß cells', 'CELL'),
#  ('islet ß-cell', 'CELL'),
#  ('ketones', 'SIMPLE_CHEMICAL'),
#  ('kidney', 'ORGAN'),
#  ('lean', 'ORGAN'),
#  ('leptin', 'GENE_OR_GENE_PRODUCT'),
#  ('lipotoxicity', 'SIMPLE_CHEMICAL'),
#  ('liver', 'ORGAN'),
#  ('liver fat.[30,31', 'MULTI-TISSUE_STRUCTURE'),
#  ('meta-analysis[26', 'GENE_OR_GENE_PRODUCT'),
#  ('microvascular', 'TISSUE'),
#  ('mother', 'ORGANISM'),
#  ('non-esterifies fatty acids', 'GENE_OR_GENE_PRODUCT'),
#  ('nonsuppressed', 'SIMPLE_CHEMICAL'),
#  ('organ', 'ORGAN'),
#  ('organs', 'ORGAN'),
#  ('pancreas', 'ORGAN'),
#  ('pancreatic a-cell', 'CANCER'),
#  ('pancreatic ß-cell', 'CANCER'),
#  ('patients', 'ORGANISM'),
#  ('people', 'ORGANISM'),
#  ('peripheral insulin', 'ORGANISM_SUBSTANCE'),
#  ('placental hormones', 'CELLULAR_COMPONENT'),
#  ('prandial GLP- 1', 'GENE_OR_GENE_PRODUCT'),
#  ('pregnancy[22', 'GENE_OR_GENE_PRODUCT'),
#  ('progesterone', 'SIMPLE_CHEMICAL'),
#  ('prolactin', 'GENE_OR_GENE_PRODUCT'),
#  ('retina', 'MULTI-TISSUE_STRUCTURE'),
#  ('secretory', 'CELLULAR_COMPONENT'),
#  ('skeletal muscle', 'TISSUE'),
#  ('starves', 'CELL'),
#  ('stomach', 'ORGAN'),
#  ('subcutaneous adipose tissue', 'TISSUE'),
#  ('sugar', 'SIMPLE_CHEMICAL'),
#  ('tissue', 'TISSUE'),
#  ('tissue necrosis factor', 'GENE_OR_GENE_PRODUCT'),
#  ('tissues', 'TISSUE'),
#  ('tumour necrosis factor', 'GENE_OR_GENE_PRODUCT'),
#  ('type 1 diabetes', 'GENE_OR_GENE_PRODUCT'),
#  ('type 2 diabetes[7-13', 'GENE_OR_GENE_PRODUCT'),
#  ('visceral adipose tissue', 'TISSUE'),
#  ('women', 'ORGANISM'),
#  ('year[23', 'SIMPLE_CHEMICAL'),
#  ('ß cell', 'CELL'),
#  ('ß cells', 'CELL'),
#  ('ß-cell', 'GENE_OR_GENE_PRODUCT'),
#  ('ß-cells', 'CELL'),
#  ('’s', 'GENE_OR_GENE_PRODUCT'),
#  ('”', 'GENE_OR_GENE_PRODUCT')}

# %% [markdown]
#    **The function show_medical_abbreviation() accepts a model and document to return abbreviated words and their resolutions. The function can be adjusted as needed. I set the list so only unique values are returned**

# %%
from scispacy.abbreviation import AbbreviationDetector

# %%
def show_med_abbreviation(model, text):
    scinlp = spacy.load(model)
    abbreviation_pipe = AbbreviationDetector(scinlp)
    scinlp.add_pipe(abbreviation_pipe)
    doc = scinlp(text)
    abbreviated = list(set([f'{abrv} {abrv._.long_form}' for abrv in doc._.abbreviations]))
    return  abbreviated

# %%
show_med_abbreviation('en_ner_bc5cdr_md', text)
# Out:
# ['GLP-1 glucagon-like peptide 1',
#  'GAD glutamic acid decarboxylase',
#  'SAT subcutaneous adipose tissue',
#  'DKA Diabetic ketoacidosis',
#  'DM Diabetes mellitus',
#  'IAA insulin autoantibody',
#  'VAT visceral adipose tissue',
#  'GDM Gestational diabetes mellitus']

# %% [markdown]
# References
#
# scispaCy is a Python package containing spaCy models for processing biomedical, scientific or clinical text. https://allenai.github.io/scispacy/
#
#
# https://medium.com/@oyewusiwuraola/how-to-use-scispacy-for-biomedical-named-entity-recognition-abbreviation-resolution-and-link-umls-87d3f7c08db2
